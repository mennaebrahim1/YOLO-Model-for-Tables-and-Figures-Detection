# %%
import xml.etree.ElementTree as ET
import os
import shutil

# Define paths
input_folder = r"C:\Users\me513\Downloads\images"# Folder containing multiple subfolders with XML and image files
output_labels_folder = r'C:\Users\me513\Downloads\labels'  # Folder for YOLO text files
output_images_folder = r'C:\Users\me513\Downloads\image'  # Folder for images

# Ensure output directories exist
os.makedirs(output_labels_folder, exist_ok=True)
os.makedirs(output_images_folder, exist_ok=True)

# Define image dimensions (assuming all images are the same size; adjust if necessary)
image_width = 1700
image_height = 2200

# Class mapping (adjust as needed)
class_mapping = {
    "Figure": 1,
    "Table": 0
}

# Function to convert XML to YOLO format
def convert_xml_to_yolo(xml_file, output_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    
    with open(output_file, 'w') as f:
        for obj in root.findall('object'):
            class_name = obj.find('name').text
            if class_name not in class_mapping:
                print(f"Warning: Class '{class_name}' not found in class mapping. Skipping.")
                continue  # Skip if class name not recognized

            class_id = class_mapping[class_name]

            bbox = obj.find('bndbox')
            xmin = float(bbox.find('xmin').text)
            ymin = float(bbox.find('ymin').text)
            xmax = float(bbox.find('xmax').text)
            ymax = float(bbox.find('ymax').text)

            # Convert to YOLO format (normalized)
            x_center = ((xmin + xmax) / 2) / image_width
            y_center = ((ymin + ymax) / 2) / image_height
            width = (xmax - xmin) / image_width
            height = (ymax - ymin) / image_height
            
            # Write in YOLO format
            f.write(f"{class_id} {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

# Initialize counters for naming files in ascending order
image_counter = 1
label_counter = 1

# Recursively traverse each subfolder in the input folder
for root_dir, sub_dirs, files in os.walk(input_folder):
    for filename in files:
        # Process XML files for YOLO labels
        if filename.endswith('.xml'):
            xml_file_path = os.path.join(root_dir, filename)
            # Define the output text file path with ascending order naming
            output_txt_path = os.path.join(output_labels_folder, f"{label_counter:05d}.txt")
            convert_xml_to_yolo(xml_file_path, output_txt_path)
            print(f"Converted {filename} to {output_txt_path}")
            label_counter += 1

        # Process PNG files for images
        elif filename.endswith('.png'):
            image_file_path = os.path.join(root_dir, filename)
            # Define the output image file path with ascending order naming
            output_image_path = os.path.join(output_images_folder, f"{image_counter:05d}.png")
            shutil.copy(image_file_path, output_image_path)
            print(f"Copied {filename} to {output_image_path}")
            image_counter += 1

print("All files processed successfully.")
# Out:
# Copied 00001.png to C:\Users\me513\Downloads\image\00001.png
# Converted 00001.xml to C:\Users\me513\Downloads\labels\00001.txt
# Copied 00002.png to C:\Users\me513\Downloads\image\00002.png
# Converted 00002.xml to C:\Users\me513\Downloads\labels\00002.txt
# Copied 00003.png to C:\Users\me513\Downloads\image\00003.png
# Converted 00003.xml to C:\Users\me513\Downloads\labels\00003.txt
# Copied 00004.png to C:\Users\me513\Downloads\image\00004.png
# Converted 00004.xml to C:\Users\me513\Downloads\labels\00004.txt
# Copied 00005.png to C:\Users\me513\Downloads\image\00005.png
# Converted 00005.xml to C:\Users\me513\Downloads\labels\00005.txt
# Copied 00006.png to C:\Users\me513\Downloads\image\00006.png
# Converted 00006.xml to C:\Users\me513\Downloads\labels\00006.txt
# Copied 00007.png to C:\Users\me513\Downloads\image\00007.png
# Converted 00007.xml to C:\Users\me513\Downloads\labels\00007.txt
# Copied 00008.png to C:\Users\me513\Downloads\image\00008.png
# Converted 00008.xml to C:\Users\me513\Downloads\labels\00008.txt
# Copied 00009.png to C:\Users\me513\Downloads\image\00009.png
# Converted 00009.xml to C:\Users\me513\Downloads\labels\00009.txt
# Copied 00010.png to C:\Users\me513\Downloads\image\00010.png
# Converted 00010.xml to C:\Users\me513\Downloads\labels\00010.txt
# Copied 00011.png to C:\Users\me513\Downloads\image\00011.png
# Converted 00011.xml to C:\Users\me513\Downloads\labels\00011.txt
# Copied 00012.png to C:\Users\me513\Downloads\image\00012.png
# Converted 00012.xml to C:\Users\me513\Downloads\labels\00012.txt
# Copied 00013.png to C:\Users\me513\Downloads\image\00013.png
# Converted 00013.xml to C:\Users\me513\Downloads\labels\00013.txt
# Copied 00014.png to C:\Users\me513\Downloads\image\00014.png
# Converted 00014.xml to C:\Users\me513\Downloads\labels\00014.txt
# Copied 00015.png to C:\Users\me513\Downloads\image\00015.png
# Converted 00015.xml to C:\Users\me513\Downloads\labels\00015.txt
# Copied 00016.png to C:\Users\me513\Downloads\image\00016.png
# Converted 00016.xml to C:\Users\me513\Downloads\labels\00016.txt
# Copied 00017.png to C:\Users\me513\Downloads\image\00017.png
# Converted 00017.xml to C:\Users\me513\Downloads\labels\00017.txt
# Copied 00018.png to C:\Users\me513\Downloads\image\00018.png
# Converted 00018.xml to C:\Users\me513\Downloads\labels\00018.txt
# Copied 00019.png to C:\Users\me513\Downloads\image\00019.png
# Converted 00019.xml to C:\Users\me513\Downloads\labels\00019.txt
# Copied 00020.png to C:\Users\me513\Downloads\image\00020.png
# Converted 00020.xml to C:\Users\me513\Downloads\labels\00020.txt
# Copied 00021.png to C:\Users\me513\Downloads\image\00021.png
# Converted 00021.xml to C:\Users\me513\Downloads\labels\00021.txt
# Copied 00022.png to C:\Users\me513\Downloads\image\00022.png
# Converted 00022.xml to C:\Users\me513\Downloads\labels\00022.txt
# Copied 00023.png to C:\Users\me513\Downloads\image\00023.png
# Converted 00023.xml to C:\Users\me513\Downloads\labels\00023.txt
# Copied 00024.png to C:\Users\me513\Downloads\image\00024.png
# Converted 00024.xml to C:\Users\me513\Downloads\labels\00024.txt
# Copied 00025.png to C:\Users\me513\Downloads\image\00025.png
# Converted 00025.xml to C:\Users\me513\Downloads\labels\00025.txt
# Copied 00026.png to C:\Users\me513\Downloads\image\00026.png
# Converted 00026.xml to C:\Users\me513\Downloads\labels\00026.txt
# Copied 00027.png to C:\Users\me513\Downloads\image\00027.png
# Converted 00027.xml to C:\Users\me513\Downloads\labels\00027.txt
# Copied 00028.png to C:\Users\me513\Downloads\image\00028.png
# Converted 00028.xml to C:\Users\me513\Downloads\labels\00028.txt
# Copied 00029.png to C:\Users\me513\Downloads\image\00029.png
# Converted 00029.xml to C:\Users\me513\Downloads\labels\00029.txt
# Copied 00030.png to C:\Users\me513\Downloads\image\00030.png
# Converted 00030.xml to C:\Users\me513\Downloads\labels\00030.txt
# Copied 00031.png to C:\Users\me513\Downloads\image\00031.png
# Converted 00031.xml to C:\Users\me513\Downloads\labels\00031.txt
# Copied 00032.png to C:\Users\me513\Downloads\image\00032.png
# Converted 00032.xml to C:\Users\me513\Downloads\labels\00032.txt
# Copied 00033.png to C:\Users\me513\Downloads\image\00033.png
# Converted 00033.xml to C:\Users\me513\Downloads\labels\00033.txt
# Copied 00034.png to C:\Users\me513\Downloads\image\00034.png
# Converted 00034.xml to C:\Users\me513\Downloads\labels\00034.txt
# Copied 00035.png to C:\Users\me513\Downloads\image\00035.png
# Converted 00035.xml to C:\Users\me513\Downloads\labels\00035.txt
# Copied 00036.png to C:\Users\me513\Downloads\image\00036.png
# Converted 00036.xml to C:\Users\me513\Downloads\labels\00036.txt
# Copied 00037.png to C:\Users\me513\Downloads\image\00037.png
# Converted 00037.xml to C:\Users\me513\Downloads\labels\00037.txt
# Copied 00038.png to C:\Users\me513\Downloads\image\00038.png
# Converted 00038.xml to C:\Users\me513\Downloads\labels\00038.txt
# Copied 00039.png to C:\Users\me513\Downloads\image\00039.png
# Converted 00039.xml to C:\Users\me513\Downloads\labels\00039.txt
# Copied 00040.png to C:\Users\me513\Downloads\image\00040.png
# Converted 00040.xml to C:\Users\me513\Downloads\labels\00040.txt
# Copied 00041.png to C:\Users\me513\Downloads\image\00041.png
# Converted 00041.xml to C:\Users\me513\Downloads\labels\00041.txt
# Copied 00042.png to C:\Users\me513\Downloads\image\00042.png
# Converted 00042.xml to C:\Users\me513\Downloads\labels\00042.txt
# Copied 00043.png to C:\Users\me513\Downloads\image\00043.png
# Converted 00043.xml to C:\Users\me513\Downloads\labels\00043.txt
# Copied 00044.png to C:\Users\me513\Downloads\image\00044.png
# Converted 00044.xml to C:\Users\me513\Downloads\labels\00044.txt
# Copied 00045.png to C:\Users\me513\Downloads\image\00045.png
# Converted 00045.xml to C:\Users\me513\Downloads\labels\00045.txt
# Copied 00046.png to C:\Users\me513\Downloads\image\00046.png
# Converted 00046.xml to C:\Users\me513\Downloads\labels\00046.txt
# Copied 00047.png to C:\Users\me513\Downloads\image\00047.png
# Converted 00047.xml to C:\Users\me513\Downloads\labels\00047.txt
# Copied 00048.png to C:\Users\me513\Downloads\image\00048.png
# Converted 00048.xml to C:\Users\me513\Downloads\labels\00048.txt
# Copied 00049.png to C:\Users\me513\Downloads\image\00049.png
# Converted 00049.xml to C:\Users\me513\Downloads\labels\00049.txt
# Copied 00050.png to C:\Users\me513\Downloads\image\00050.png
# Converted 00050.xml to C:\Users\me513\Downloads\labels\00050.txt
# Copied 00051.png to C:\Users\me513\Downloads\image\00051.png
# Converted 00051.xml to C:\Users\me513\Downloads\labels\00051.txt
# Copied 00052.png to C:\Users\me513\Downloads\image\00052.png
# Converted 00052.xml to C:\Users\me513\Downloads\labels\00052.txt
# Copied 00053.png to C:\Users\me513\Downloads\image\00053.png
# Converted 00053.xml to C:\Users\me513\Downloads\labels\00053.txt
# Copied 00054.png to C:\Users\me513\Downloads\image\00054.png
# Converted 00054.xml to C:\Users\me513\Downloads\labels\00054.txt
# Copied 00055.png to C:\Users\me513\Downloads\image\00055.png
# Converted 00055.xml to C:\Users\me513\Downloads\labels\00055.txt
# Copied 00056.png to C:\Users\me513\Downloads\image\00056.png
# Converted 00056.xml to C:\Users\me513\Downloads\labels\00056.txt
# Copied 00057.png to C:\Users\me513\Downloads\image\00057.png
# Converted 00057.xml to C:\Users\me513\Downloads\labels\00057.txt
# Copied 00058.png to C:\Users\me513\Downloads\image\00058.png
# Converted 00058.xml to C:\Users\me513\Downloads\labels\00058.txt
# Copied 00059.png to C:\Users\me513\Downloads\image\00059.png
# Converted 00059.xml to C:\Users\me513\Downloads\labels\00059.txt
# Copied 00060.png to C:\Users\me513\Downloads\image\00060.png
# Converted 00060.xml to C:\Users\me513\Downloads\labels\00060.txt
# Copied 00061.png to C:\Users\me513\Downloads\image\00061.png
# Converted 00061.xml to C:\Users\me513\Downloads\labels\00061.txt
# Copied 00062.png to C:\Users\me513\Downloads\image\00062.png
# Converted 00062.xml to C:\Users\me513\Downloads\labels\00062.txt
# Copied 00063.png to C:\Users\me513\Downloads\image\00063.png
# Converted 00063.xml to C:\Users\me513\Downloads\labels\00063.txt
# Copied 00064.png to C:\Users\me513\Downloads\image\00064.png
# Converted 00064.xml to C:\Users\me513\Downloads\labels\00064.txt
# Copied 00065.png to C:\Users\me513\Downloads\image\00065.png
# Converted 00065.xml to C:\Users\me513\Downloads\labels\00065.txt
# Copied 00066.png to C:\Users\me513\Downloads\image\00066.png
# Converted 00066.xml to C:\Users\me513\Downloads\labels\00066.txt
# Copied 00067.png to C:\Users\me513\Downloads\image\00067.png
# Converted 00067.xml to C:\Users\me513\Downloads\labels\00067.txt
# Copied 00068.png to C:\Users\me513\Downloads\image\00068.png
# Converted 00068.xml to C:\Users\me513\Downloads\labels\00068.txt
# Copied 00069.png to C:\Users\me513\Downloads\image\00069.png
# Converted 00069.xml to C:\Users\me513\Downloads\labels\00069.txt
# Copied 00070.png to C:\Users\me513\Downloads\image\00070.png
# Converted 00070.xml to C:\Users\me513\Downloads\labels\00070.txt
# Copied 00071.png to C:\Users\me513\Downloads\image\00071.png
# Converted 00071.xml to C:\Users\me513\Downloads\labels\00071.txt
# Copied 00072.png to C:\Users\me513\Downloads\image\00072.png
# Converted 00072.xml to C:\Users\me513\Downloads\labels\00072.txt
# Copied 00073.png to C:\Users\me513\Downloads\image\00073.png
# Converted 00073.xml to C:\Users\me513\Downloads\labels\00073.txt
# Copied 00074.png to C:\Users\me513\Downloads\image\00074.png
# Converted 00074.xml to C:\Users\me513\Downloads\labels\00074.txt
# Copied 00075.png to C:\Users\me513\Downloads\image\00075.png
# Converted 00075.xml to C:\Users\me513\Downloads\labels\00075.txt
# Copied 00076.png to C:\Users\me513\Downloads\image\00076.png
# Converted 00076.xml to C:\Users\me513\Downloads\labels\00076.txt
# Copied 00077.png to C:\Users\me513\Downloads\image\00077.png
# Converted 00077.xml to C:\Users\me513\Downloads\labels\00077.txt
# Copied 00078.png to C:\Users\me513\Downloads\image\00078.png
# Converted 00078.xml to C:\Users\me513\Downloads\labels\00078.txt
# Copied 00079.png to C:\Users\me513\Downloads\image\00079.png
# Converted 00079.xml to C:\Users\me513\Downloads\labels\00079.txt
# Copied 00080.png to C:\Users\me513\Downloads\image\00080.png
# Converted 00080.xml to C:\Users\me513\Downloads\labels\00080.txt
# Copied 00081.png to C:\Users\me513\Downloads\image\00081.png
# Converted 00081.xml to C:\Users\me513\Downloads\labels\00081.txt
# Copied 00082.png to C:\Users\me513\Downloads\image\00082.png
# Converted 00082.xml to C:\Users\me513\Downloads\labels\00082.txt
# Copied 00083.png to C:\Users\me513\Downloads\image\00083.png
# Converted 00083.xml to C:\Users\me513\Downloads\labels\00083.txt
# Copied 00084.png to C:\Users\me513\Downloads\image\00084.png
# Converted 00084.xml to C:\Users\me513\Downloads\labels\00084.txt
# Copied 00085.png to C:\Users\me513\Downloads\image\00085.png
# Converted 00085.xml to C:\Users\me513\Downloads\labels\00085.txt
# Copied 00086.png to C:\Users\me513\Downloads\image\00086.png
# Converted 00086.xml to C:\Users\me513\Downloads\labels\00086.txt
# Copied 00087.png to C:\Users\me513\Downloads\image\00087.png
# Converted 00087.xml to C:\Users\me513\Downloads\labels\00087.txt
# Copied 00088.png to C:\Users\me513\Downloads\image\00088.png
# Converted 00088.xml to C:\Users\me513\Downloads\labels\00088.txt
# Copied 00089.png to C:\Users\me513\Downloads\image\00089.png
# Converted 00089.xml to C:\Users\me513\Downloads\labels\00089.txt
# Copied 00090.png to C:\Users\me513\Downloads\image\00090.png
# Converted 00090.xml to C:\Users\me513\Downloads\labels\00090.txt
# Copied 00091.png to C:\Users\me513\Downloads\image\00091.png
# Converted 00091.xml to C:\Users\me513\Downloads\labels\00091.txt
# Copied 00092.png to C:\Users\me513\Downloads\image\00092.png
# Converted 00092.xml to C:\Users\me513\Downloads\labels\00092.txt
# Copied 00093.png to C:\Users\me513\Downloads\image\00093.png
# Converted 00093.xml to C:\Users\me513\Downloads\labels\00093.txt
# Copied 00094.png to C:\Users\me513\Downloads\image\00094.png
# Converted 00094.xml to C:\Users\me513\Downloads\labels\00094.txt
# Copied 00095.png to C:\Users\me513\Downloads\image\00095.png
# Converted 00095.xml to C:\Users\me513\Downloads\labels\00095.txt
# Copied 00096.png to C:\Users\me513\Downloads\image\00096.png
# Converted 00096.xml to C:\Users\me513\Downloads\labels\00096.txt
# Copied 00097.png to C:\Users\me513\Downloads\image\00097.png
# Converted 00097.xml to C:\Users\me513\Downloads\labels\00097.txt
# Copied 00098.png to C:\Users\me513\Downloads\image\00098.png
# Converted 00098.xml to C:\Users\me513\Downloads\labels\00098.txt
# Copied 00099.png to C:\Users\me513\Downloads\image\00099.png
# Converted 00099.xml to C:\Users\me513\Downloads\labels\00099.txt
# Copied 00100.png to C:\Users\me513\Downloads\image\00100.png
# Converted 00100.xml to C:\Users\me513\Downloads\labels\00100.txt
# Copied 00101.png to C:\Users\me513\Downloads\image\00101.png
# Converted 00101.xml to C:\Users\me513\Downloads\labels\00101.txt
# Copied 00102.png to C:\Users\me513\Downloads\image\00102.png
# Converted 00102.xml to C:\Users\me513\Downloads\labels\00102.txt
# Copied 00103.png to C:\Users\me513\Downloads\image\00103.png
# Converted 00103.xml to C:\Users\me513\Downloads\labels\00103.txt
# Copied 00104.png to C:\Users\me513\Downloads\image\00104.png
# Converted 00104.xml to C:\Users\me513\Downloads\labels\00104.txt
# Copied 00105.png to C:\Users\me513\Downloads\image\00105.png
# Converted 00105.xml to C:\Users\me513\Downloads\labels\00105.txt
# Copied 00106.png to C:\Users\me513\Downloads\image\00106.png
# Converted 00106.xml to C:\Users\me513\Downloads\labels\00106.txt
# Copied 00107.png to C:\Users\me513\Downloads\image\00107.png
# Converted 00107.xml to C:\Users\me513\Downloads\labels\00107.txt
# Copied 00108.png to C:\Users\me513\Downloads\image\00108.png
# Converted 00108.xml to C:\Users\me513\Downloads\labels\00108.txt
# Copied 00109.png to C:\Users\me513\Downloads\image\00109.png
# Converted 00109.xml to C:\Users\me513\Downloads\labels\00109.txt
# Copied 00110.png to C:\Users\me513\Downloads\image\00110.png
# Converted 00110.xml to C:\Users\me513\Downloads\labels\00110.txt
# Copied 00111.png to C:\Users\me513\Downloads\image\00111.png
# Converted 00111.xml to C:\Users\me513\Downloads\labels\00111.txt
# Copied 00112.png to C:\Users\me513\Downloads\image\00112.png
# Converted 00112.xml to C:\Users\me513\Downloads\labels\00112.txt
# Copied 00113.png to C:\Users\me513\Downloads\image\00113.png
# Converted 00113.xml to C:\Users\me513\Downloads\labels\00113.txt
# Copied 00114.png to C:\Users\me513\Downloads\image\00114.png
# Converted 00114.xml to C:\Users\me513\Downloads\labels\00114.txt
# Copied 00115.png to C:\Users\me513\Downloads\image\00115.png
# Converted 00115.xml to C:\Users\me513\Downloads\labels\00115.txt
# Copied 00116.png to C:\Users\me513\Downloads\image\00116.png
# Converted 00116.xml to C:\Users\me513\Downloads\labels\00116.txt
# Copied 00117.png to C:\Users\me513\Downloads\image\00117.png
# Converted 00117.xml to C:\Users\me513\Downloads\labels\00117.txt
# Copied 00118.png to C:\Users\me513\Downloads\image\00118.png
# Converted 00118.xml to C:\Users\me513\Downloads\labels\00118.txt
# Copied 00119.png to C:\Users\me513\Downloads\image\00119.png
# Converted 00119.xml to C:\Users\me513\Downloads\labels\00119.txt
# Copied 00120.png to C:\Users\me513\Downloads\image\00120.png
# Converted 00120.xml to C:\Users\me513\Downloads\labels\00120.txt
# Copied 00121.png to C:\Users\me513\Downloads\image\00121.png
# Converted 00121.xml to C:\Users\me513\Downloads\labels\00121.txt
# Copied 00122.png to C:\Users\me513\Downloads\image\00122.png
# Converted 00122.xml to C:\Users\me513\Downloads\labels\00122.txt
# Copied 00123.png to C:\Users\me513\Downloads\image\00123.png
# Converted 00123.xml to C:\Users\me513\Downloads\labels\00123.txt
# Copied 00124.png to C:\Users\me513\Downloads\image\00124.png
# Converted 00124.xml to C:\Users\me513\Downloads\labels\00124.txt
# Copied 00125.png to C:\Users\me513\Downloads\image\00125.png
# Converted 00125.xml to C:\Users\me513\Downloads\labels\00125.txt
# Copied 00126.png to C:\Users\me513\Downloads\image\00126.png
# Converted 00126.xml to C:\Users\me513\Downloads\labels\00126.txt
# Copied 00127.png to C:\Users\me513\Downloads\image\00127.png
# Converted 00127.xml to C:\Users\me513\Downloads\labels\00127.txt
# Copied 00128.png to C:\Users\me513\Downloads\image\00128.png
# Converted 00128.xml to C:\Users\me513\Downloads\labels\00128.txt
# Copied 00129.png to C:\Users\me513\Downloads\image\00129.png
# Converted 00129.xml to C:\Users\me513\Downloads\labels\00129.txt
# Copied 00130.png to C:\Users\me513\Downloads\image\00130.png
# Converted 00130.xml to C:\Users\me513\Downloads\labels\00130.txt
# Copied 00131.png to C:\Users\me513\Downloads\image\00131.png
# Converted 00131.xml to C:\Users\me513\Downloads\labels\00131.txt
# Copied 00132.png to C:\Users\me513\Downloads\image\00132.png
# Converted 00132.xml to C:\Users\me513\Downloads\labels\00132.txt
# Copied 00133.png to C:\Users\me513\Downloads\image\00133.png
# Converted 00133.xml to C:\Users\me513\Downloads\labels\00133.txt
# Copied 00134.png to C:\Users\me513\Downloads\image\00134.png
# Converted 00134.xml to C:\Users\me513\Downloads\labels\00134.txt
# Copied 00135.png to C:\Users\me513\Downloads\image\00135.png
# Converted 00135.xml to C:\Users\me513\Downloads\labels\00135.txt
# Copied 00136.png to C:\Users\me513\Downloads\image\00136.png
# Converted 00136.xml to C:\Users\me513\Downloads\labels\00136.txt
# Copied 00137.png to C:\Users\me513\Downloads\image\00137.png
# Converted 00137.xml to C:\Users\me513\Downloads\labels\00137.txt
# Copied 00138.png to C:\Users\me513\Downloads\image\00138.png
# Converted 00138.xml to C:\Users\me513\Downloads\labels\00138.txt
# Copied 00139.png to C:\Users\me513\Downloads\image\00139.png
# Converted 00139.xml to C:\Users\me513\Downloads\labels\00139.txt
# Copied 00140.png to C:\Users\me513\Downloads\image\00140.png
# Converted 00140.xml to C:\Users\me513\Downloads\labels\00140.txt
# Copied 00141.png to C:\Users\me513\Downloads\image\00141.png
# Converted 00141.xml to C:\Users\me513\Downloads\labels\00141.txt
# Copied 00142.png to C:\Users\me513\Downloads\image\00142.png
# Converted 00142.xml to C:\Users\me513\Downloads\labels\00142.txt
# Copied 00143.png to C:\Users\me513\Downloads\image\00143.png
# Converted 00143.xml to C:\Users\me513\Downloads\labels\00143.txt
# Copied 00144.png to C:\Users\me513\Downloads\image\00144.png
# Converted 00144.xml to C:\Users\me513\Downloads\labels\00144.txt
# Copied 00145.png to C:\Users\me513\Downloads\image\00145.png
# Converted 00145.xml to C:\Users\me513\Downloads\labels\00145.txt
# Copied 00146.png to C:\Users\me513\Downloads\image\00146.png
# Converted 00146.xml to C:\Users\me513\Downloads\labels\00146.txt
# Copied 00147.png to C:\Users\me513\Downloads\image\00147.png
# Converted 00147.xml to C:\Users\me513\Downloads\labels\00147.txt
# Copied 00148.png to C:\Users\me513\Downloads\image\00148.png
# Converted 00148.xml to C:\Users\me513\Downloads\labels\00148.txt
# Copied 00149.png to C:\Users\me513\Downloads\image\00149.png
# Converted 00149.xml to C:\Users\me513\Downloads\labels\00149.txt
# Copied 00150.png to C:\Users\me513\Downloads\image\00150.png
# Converted 00150.xml to C:\Users\me513\Downloads\labels\00150.txt
# Copied 00151.png to C:\Users\me513\Downloads\image\00151.png
# Converted 00151.xml to C:\Users\me513\Downloads\labels\00151.txt
# Copied 00152.png to C:\Users\me513\Downloads\image\00152.png
# Converted 00152.xml to C:\Users\me513\Downloads\labels\00152.txt
# Copied 00153.png to C:\Users\me513\Downloads\image\00153.png
# Converted 00153.xml to C:\Users\me513\Downloads\labels\00153.txt
# Copied 00154.png to C:\Users\me513\Downloads\image\00154.png
# Converted 00154.xml to C:\Users\me513\Downloads\labels\00154.txt
# Copied 00155.png to C:\Users\me513\Downloads\image\00155.png
# Converted 00155.xml to C:\Users\me513\Downloads\labels\00155.txt
# Copied 00156.png to C:\Users\me513\Downloads\image\00156.png
# Converted 00156.xml to C:\Users\me513\Downloads\labels\00156.txt
# Copied 00157.png to C:\Users\me513\Downloads\image\00157.png
# Converted 00157.xml to C:\Users\me513\Downloads\labels\00157.txt
# Copied 00158.png to C:\Users\me513\Downloads\image\00158.png
# Converted 00158.xml to C:\Users\me513\Downloads\labels\00158.txt
# Copied 00159.png to C:\Users\me513\Downloads\image\00159.png
# Converted 00159.xml to C:\Users\me513\Downloads\labels\00159.txt
# Copied 00160.png to C:\Users\me513\Downloads\image\00160.png
# Converted 00160.xml to C:\Users\me513\Downloads\labels\00160.txt
# Copied 00161.png to C:\Users\me513\Downloads\image\00161.png
# Converted 00161.xml to C:\Users\me513\Downloads\labels\00161.txt
# Copied 00162.png to C:\Users\me513\Downloads\image\00162.png
# Converted 00162.xml to C:\Users\me513\Downloads\labels\00162.txt
# Copied 00163.png to C:\Users\me513\Downloads\image\00163.png
# Converted 00163.xml to C:\Users\me513\Downloads\labels\00163.txt
# Copied 00164.png to C:\Users\me513\Downloads\image\00164.png
# Converted 00164.xml to C:\Users\me513\Downloads\labels\00164.txt
# Copied 00165.png to C:\Users\me513\Downloads\image\00165.png
# Converted 00165.xml to C:\Users\me513\Downloads\labels\00165.txt
# Copied 00166.png to C:\Users\me513\Downloads\image\00166.png
# Converted 00166.xml to C:\Users\me513\Downloads\labels\00166.txt
# Copied 00167.png to C:\Users\me513\Downloads\image\00167.png
# Converted 00167.xml to C:\Users\me513\Downloads\labels\00167.txt
# Copied 00168.png to C:\Users\me513\Downloads\image\00168.png
# Converted 00168.xml to C:\Users\me513\Downloads\labels\00168.txt
# Copied 00169.png to C:\Users\me513\Downloads\image\00169.png
# Converted 00169.xml to C:\Users\me513\Downloads\labels\00169.txt
# Copied 00170.png to C:\Users\me513\Downloads\image\00170.png
# Converted 00170.xml to C:\Users\me513\Downloads\labels\00170.txt
# Copied 00171.png to C:\Users\me513\Downloads\image\00171.png
# Converted 00171.xml to C:\Users\me513\Downloads\labels\00171.txt
# Copied 00172.png to C:\Users\me513\Downloads\image\00172.png
# Converted 00172.xml to C:\Users\me513\Downloads\labels\00172.txt
# Copied 00173.png to C:\Users\me513\Downloads\image\00173.png
# Converted 00173.xml to C:\Users\me513\Downloads\labels\00173.txt
# Copied 00174.png to C:\Users\me513\Downloads\image\00174.png
# Converted 00174.xml to C:\Users\me513\Downloads\labels\00174.txt
# Copied 00175.png to C:\Users\me513\Downloads\image\00175.png
# Converted 00175.xml to C:\Users\me513\Downloads\labels\00175.txt
# Copied 00176.png to C:\Users\me513\Downloads\image\00176.png
# Converted 00176.xml to C:\Users\me513\Downloads\labels\00176.txt
# Copied 00177.png to C:\Users\me513\Downloads\image\00177.png
# Converted 00177.xml to C:\Users\me513\Downloads\labels\00177.txt
# Copied 00178.png to C:\Users\me513\Downloads\image\00178.png
# Converted 00178.xml to C:\Users\me513\Downloads\labels\00178.txt
# Copied 00179.png to C:\Users\me513\Downloads\image\00179.png
# Converted 00179.xml to C:\Users\me513\Downloads\labels\00179.txt
# Copied 00180.png to C:\Users\me513\Downloads\image\00180.png
# Converted 00180.xml to C:\Users\me513\Downloads\labels\00180.txt
# Copied 00181.png to C:\Users\me513\Downloads\image\00181.png
# Converted 00181.xml to C:\Users\me513\Downloads\labels\00181.txt
# Copied 00182.png to C:\Users\me513\Downloads\image\00182.png
# Converted 00182.xml to C:\Users\me513\Downloads\labels\00182.txt
# Copied 00183.png to C:\Users\me513\Downloads\image\00183.png
# Converted 00183.xml to C:\Users\me513\Downloads\labels\00183.txt
# Copied 00184.png to C:\Users\me513\Downloads\image\00184.png
# Converted 00184.xml to C:\Users\me513\Downloads\labels\00184.txt
# Copied 00185.png to C:\Users\me513\Downloads\image\00185.png
# Converted 00185.xml to C:\Users\me513\Downloads\labels\00185.txt
# Copied 00186.png to C:\Users\me513\Downloads\image\00186.png
# Converted 00186.xml to C:\Users\me513\Downloads\labels\00186.txt
# Copied 00187.png to C:\Users\me513\Downloads\image\00187.png
# Converted 00187.xml to C:\Users\me513\Downloads\labels\00187.txt
# Copied 00188.png to C:\Users\me513\Downloads\image\00188.png
# Converted 00188.xml to C:\Users\me513\Downloads\labels\00188.txt
# Copied 00189.png to C:\Users\me513\Downloads\image\00189.png
# Converted 00189.xml to C:\Users\me513\Downloads\labels\00189.txt
# Copied 00190.png to C:\Users\me513\Downloads\image\00190.png
# Converted 00190.xml to C:\Users\me513\Downloads\labels\00190.txt
# Copied 00191.png to C:\Users\me513\Downloads\image\00191.png
# Converted 00191.xml to C:\Users\me513\Downloads\labels\00191.txt
# Copied 00192.png to C:\Users\me513\Downloads\image\00192.png
# Converted 00192.xml to C:\Users\me513\Downloads\labels\00192.txt
# Copied 00193.png to C:\Users\me513\Downloads\image\00193.png
# Converted 00193.xml to C:\Users\me513\Downloads\labels\00193.txt
# Copied 00194.png to C:\Users\me513\Downloads\image\00194.png
# Converted 00194.xml to C:\Users\me513\Downloads\labels\00194.txt
# Copied 00195.png to C:\Users\me513\Downloads\image\00195.png
# Converted 00195.xml to C:\Users\me513\Downloads\labels\00195.txt
# Copied 00196.png to C:\Users\me513\Downloads\image\00196.png
# Converted 00196.xml to C:\Users\me513\Downloads\labels\00196.txt
# Copied 00197.png to C:\Users\me513\Downloads\image\00197.png
# Converted 00197.xml to C:\Users\me513\Downloads\labels\00197.txt
# Copied 00198.png to C:\Users\me513\Downloads\image\00198.png
# Converted 00198.xml to C:\Users\me513\Downloads\labels\00198.txt
# Copied 00199.png to C:\Users\me513\Downloads\image\00199.png
# Converted 00199.xml to C:\Users\me513\Downloads\labels\00199.txt
# Copied 00200.png to C:\Users\me513\Downloads\image\00200.png
# Converted 00200.xml to C:\Users\me513\Downloads\labels\00200.txt
# Copied 00201.png to C:\Users\me513\Downloads\image\00201.png
# Converted 00201.xml to C:\Users\me513\Downloads\labels\00201.txt
# Copied 00202.png to C:\Users\me513\Downloads\image\00202.png
# Converted 00202.xml to C:\Users\me513\Downloads\labels\00202.txt
# Copied 00203.png to C:\Users\me513\Downloads\image\00203.png
# Converted 00203.xml to C:\Users\me513\Downloads\labels\00203.txt
# Copied 00204.png to C:\Users\me513\Downloads\image\00204.png
# Converted 00204.xml to C:\Users\me513\Downloads\labels\00204.txt
# Copied 00205.png to C:\Users\me513\Downloads\image\00205.png
# Converted 00205.xml to C:\Users\me513\Downloads\labels\00205.txt
# Copied 00206.png to C:\Users\me513\Downloads\image\00206.png
# Converted 00206.xml to C:\Users\me513\Downloads\labels\00206.txt
# Copied 00207.png to C:\Users\me513\Downloads\image\00207.png
# Converted 00207.xml to C:\Users\me513\Downloads\labels\00207.txt
# Copied 00208.png to C:\Users\me513\Downloads\image\00208.png
# Converted 00208.xml to C:\Users\me513\Downloads\labels\00208.txt
# Copied 00209.png to C:\Users\me513\Downloads\image\00209.png
# Converted 00209.xml to C:\Users\me513\Downloads\labels\00209.txt
# Copied 00210.png to C:\Users\me513\Downloads\image\00210.png
# Converted 00210.xml to C:\Users\me513\Downloads\labels\00210.txt
# Copied 00211.png to C:\Users\me513\Downloads\image\00211.png
# Converted 00211.xml to C:\Users\me513\Downloads\labels\00211.txt
# Copied 00212.png to C:\Users\me513\Downloads\image\00212.png
# Converted 00212.xml to C:\Users\me513\Downloads\labels\00212.txt
# Copied 00213.png to C:\Users\me513\Downloads\image\00213.png
# Converted 00213.xml to C:\Users\me513\Downloads\labels\00213.txt
# Copied 00214.png to C:\Users\me513\Downloads\image\00214.png
# Converted 00214.xml to C:\Users\me513\Downloads\labels\00214.txt
# Copied 00215.png to C:\Users\me513\Downloads\image\00215.png
# Converted 00215.xml to C:\Users\me513\Downloads\labels\00215.txt
# Copied 00216.png to C:\Users\me513\Downloads\image\00216.png
# Converted 00216.xml to C:\Users\me513\Downloads\labels\00216.txt
# Copied 00217.png to C:\Users\me513\Downloads\image\00217.png
# Converted 00217.xml to C:\Users\me513\Downloads\labels\00217.txt
# Copied 00218.png to C:\Users\me513\Downloads\image\00218.png
# Converted 00218.xml to C:\Users\me513\Downloads\labels\00218.txt
# Copied 00219.png to C:\Users\me513\Downloads\image\00219.png
# Converted 00219.xml to C:\Users\me513\Downloads\labels\00219.txt
# Copied 00220.png to C:\Users\me513\Downloads\image\00220.png
# Converted 00220.xml to C:\Users\me513\Downloads\labels\00220.txt
# Copied 00221.png to C:\Users\me513\Downloads\image\00221.png
# Converted 00221.xml to C:\Users\me513\Downloads\labels\00221.txt
# Copied 00222.png to C:\Users\me513\Downloads\image\00222.png
# Converted 00222.xml to C:\Users\me513\Downloads\labels\00222.txt
# Copied 00223.png to C:\Users\me513\Downloads\image\00223.png
# Converted 00223.xml to C:\Users\me513\Downloads\labels\00223.txt
# Copied 00224.png to C:\Users\me513\Downloads\image\00224.png
# Converted 00224.xml to C:\Users\me513\Downloads\labels\00224.txt
# Copied 00225.png to C:\Users\me513\Downloads\image\00225.png
# Converted 00225.xml to C:\Users\me513\Downloads\labels\00225.txt
# Copied 00226.png to C:\Users\me513\Downloads\image\00226.png
# Converted 00226.xml to C:\Users\me513\Downloads\labels\00226.txt
# Copied 00227.png to C:\Users\me513\Downloads\image\00227.png
# Converted 00227.xml to C:\Users\me513\Downloads\labels\00227.txt
# Copied 00228.png to C:\Users\me513\Downloads\image\00228.png
# Converted 00228.xml to C:\Users\me513\Downloads\labels\00228.txt
# Copied 00229.png to C:\Users\me513\Downloads\image\00229.png
# Converted 00229.xml to C:\Users\me513\Downloads\labels\00229.txt
# Copied 00230.png to C:\Users\me513\Downloads\image\00230.png
# Converted 00230.xml to C:\Users\me513\Downloads\labels\00230.txt
# Copied 00231.png to C:\Users\me513\Downloads\image\00231.png
# Converted 00231.xml to C:\Users\me513\Downloads\labels\00231.txt
# Copied 00232.png to C:\Users\me513\Downloads\image\00232.png
# Converted 00232.xml to C:\Users\me513\Downloads\labels\00232.txt
# Copied 00233.png to C:\Users\me513\Downloads\image\00233.png
# Converted 00233.xml to C:\Users\me513\Downloads\labels\00233.txt
# Copied 00234.png to C:\Users\me513\Downloads\image\00234.png
# Converted 00234.xml to C:\Users\me513\Downloads\labels\00234.txt
# Copied 00235.png to C:\Users\me513\Downloads\image\00235.png
# Converted 00235.xml to C:\Users\me513\Downloads\labels\00235.txt
# Copied 00236.png to C:\Users\me513\Downloads\image\00236.png
# Converted 00236.xml to C:\Users\me513\Downloads\labels\00236.txt
# Copied 00237.png to C:\Users\me513\Downloads\image\00237.png
# Converted 00237.xml to C:\Users\me513\Downloads\labels\00237.txt
# Copied 00238.png to C:\Users\me513\Downloads\image\00238.png
# Converted 00238.xml to C:\Users\me513\Downloads\labels\00238.txt
# Copied 00239.png to C:\Users\me513\Downloads\image\00239.png
# Converted 00239.xml to C:\Users\me513\Downloads\labels\00239.txt
# Copied 00240.png to C:\Users\me513\Downloads\image\00240.png
# Converted 00240.xml to C:\Users\me513\Downloads\labels\00240.txt
# Copied 00241.png to C:\Users\me513\Downloads\image\00241.png
# Converted 00241.xml to C:\Users\me513\Downloads\labels\00241.txt
# Copied 00242.png to C:\Users\me513\Downloads\image\00242.png
# Converted 00242.xml to C:\Users\me513\Downloads\labels\00242.txt
# Copied 00243.png to C:\Users\me513\Downloads\image\00243.png
# Converted 00243.xml to C:\Users\me513\Downloads\labels\00243.txt
# Copied 00244.png to C:\Users\me513\Downloads\image\00244.png
# Converted 00244.xml to C:\Users\me513\Downloads\labels\00244.txt
# Copied 00245.png to C:\Users\me513\Downloads\image\00245.png
# Converted 00245.xml to C:\Users\me513\Downloads\labels\00245.txt
# Copied 00246.png to C:\Users\me513\Downloads\image\00246.png
# Converted 00246.xml to C:\Users\me513\Downloads\labels\00246.txt
# Copied 00247.png to C:\Users\me513\Downloads\image\00247.png
# Converted 00247.xml to C:\Users\me513\Downloads\labels\00247.txt
# Copied 00248.png to C:\Users\me513\Downloads\image\00248.png
# Converted 00248.xml to C:\Users\me513\Downloads\labels\00248.txt
# Copied 00249.png to C:\Users\me513\Downloads\image\00249.png
# Converted 00249.xml to C:\Users\me513\Downloads\labels\00249.txt
# Copied 00250.png to C:\Users\me513\Downloads\image\00250.png
# Converted 00250.xml to C:\Users\me513\Downloads\labels\00250.txt
# Copied 00251.png to C:\Users\me513\Downloads\image\00251.png
# Converted 00251.xml to C:\Users\me513\Downloads\labels\00251.txt
# Copied 00252.png to C:\Users\me513\Downloads\image\00252.png
# Converted 00252.xml to C:\Users\me513\Downloads\labels\00252.txt
# Copied 00253.png to C:\Users\me513\Downloads\image\00253.png
# Converted 00253.xml to C:\Users\me513\Downloads\labels\00253.txt
# Copied 00254.png to C:\Users\me513\Downloads\image\00254.png
# Converted 00254.xml to C:\Users\me513\Downloads\labels\00254.txt
# Copied 00255.png to C:\Users\me513\Downloads\image\00255.png
# Converted 00255.xml to C:\Users\me513\Downloads\labels\00255.txt
# Copied 00256.png to C:\Users\me513\Downloads\image\00256.png
# Converted 00256.xml to C:\Users\me513\Downloads\labels\00256.txt
# Copied 00257.png to C:\Users\me513\Downloads\image\00257.png
# Converted 00257.xml to C:\Users\me513\Downloads\labels\00257.txt
# Copied 00258.png to C:\Users\me513\Downloads\image\00258.png
# Converted 00258.xml to C:\Users\me513\Downloads\labels\00258.txt
# Copied 00259.png to C:\Users\me513\Downloads\image\00259.png
# Converted 00259.xml to C:\Users\me513\Downloads\labels\00259.txt
# Copied 00260.png to C:\Users\me513\Downloads\image\00260.png
# Converted 00260.xml to C:\Users\me513\Downloads\labels\00260.txt
# Copied 00261.png to C:\Users\me513\Downloads\image\00261.png
# Converted 00261.xml to C:\Users\me513\Downloads\labels\00261.txt
# Copied 00262.png to C:\Users\me513\Downloads\image\00262.png
# Converted 00262.xml to C:\Users\me513\Downloads\labels\00262.txt
# Copied 00263.png to C:\Users\me513\Downloads\image\00263.png
# Converted 00263.xml to C:\Users\me513\Downloads\labels\00263.txt
# Copied 00264.png to C:\Users\me513\Downloads\image\00264.png
# Converted 00264.xml to C:\Users\me513\Downloads\labels\00264.txt
# Copied 00265.png to C:\Users\me513\Downloads\image\00265.png
# Converted 00265.xml to C:\Users\me513\Downloads\labels\00265.txt
# Copied 00266.png to C:\Users\me513\Downloads\image\00266.png
# Converted 00266.xml to C:\Users\me513\Downloads\labels\00266.txt
# Copied 00267.png to C:\Users\me513\Downloads\image\00267.png
# Converted 00267.xml to C:\Users\me513\Downloads\labels\00267.txt
# Copied 00268.png to C:\Users\me513\Downloads\image\00268.png
# Converted 00268.xml to C:\Users\me513\Downloads\labels\00268.txt
# Copied 00269.png to C:\Users\me513\Downloads\image\00269.png
# Converted 00269.xml to C:\Users\me513\Downloads\labels\00269.txt
# Copied 00270.png to C:\Users\me513\Downloads\image\00270.png
# Converted 00270.xml to C:\Users\me513\Downloads\labels\00270.txt
# Copied 00271.png to C:\Users\me513\Downloads\image\00271.png
# Converted 00271.xml to C:\Users\me513\Downloads\labels\00271.txt
# Copied 00272.png to C:\Users\me513\Downloads\image\00272.png
# Converted 00272.xml to C:\Users\me513\Downloads\labels\00272.txt
# Copied 00273.png to C:\Users\me513\Downloads\image\00273.png
# Converted 00273.xml to C:\Users\me513\Downloads\labels\00273.txt
# Copied 00274.png to C:\Users\me513\Downloads\image\00274.png
# Converted 00274.xml to C:\Users\me513\Downloads\labels\00274.txt
# Copied 00275.png to C:\Users\me513\Downloads\image\00275.png
# Converted 00275.xml to C:\Users\me513\Downloads\labels\00275.txt
# Copied 00276.png to C:\Users\me513\Downloads\image\00276.png
# Converted 00276.xml to C:\Users\me513\Downloads\labels\00276.txt
# Copied 00277.png to C:\Users\me513\Downloads\image\00277.png
# Converted 00277.xml to C:\Users\me513\Downloads\labels\00277.txt
# Copied 00278.png to C:\Users\me513\Downloads\image\00278.png
# Converted 00278.xml to C:\Users\me513\Downloads\labels\00278.txt
# Copied 00279.png to C:\Users\me513\Downloads\image\00279.png
# Converted 00279.xml to C:\Users\me513\Downloads\labels\00279.txt
# Copied 00280.png to C:\Users\me513\Downloads\image\00280.png
# Converted 00280.xml to C:\Users\me513\Downloads\labels\00280.txt
# Copied 00281.png to C:\Users\me513\Downloads\image\00281.png
# Converted 00281.xml to C:\Users\me513\Downloads\labels\00281.txt
# Copied 00282.png to C:\Users\me513\Downloads\image\00282.png
# Converted 00282.xml to C:\Users\me513\Downloads\labels\00282.txt
# Copied 00283.png to C:\Users\me513\Downloads\image\00283.png
# Converted 00283.xml to C:\Users\me513\Downloads\labels\00283.txt
# Copied 00284.png to C:\Users\me513\Downloads\image\00284.png
# Converted 00284.xml to C:\Users\me513\Downloads\labels\00284.txt
# Copied 00285.png to C:\Users\me513\Downloads\image\00285.png
# Converted 00285.xml to C:\Users\me513\Downloads\labels\00285.txt
# Copied 00286.png to C:\Users\me513\Downloads\image\00286.png
# Converted 00286.xml to C:\Users\me513\Downloads\labels\00286.txt
# Copied 00287.png to C:\Users\me513\Downloads\image\00287.png
# Converted 00287.xml to C:\Users\me513\Downloads\labels\00287.txt
# Copied 00288.png to C:\Users\me513\Downloads\image\00288.png
# Converted 00288.xml to C:\Users\me513\Downloads\labels\00288.txt
# Copied 00289.png to C:\Users\me513\Downloads\image\00289.png
# Converted 00289.xml to C:\Users\me513\Downloads\labels\00289.txt
# Copied 00290.png to C:\Users\me513\Downloads\image\00290.png
# Converted 00290.xml to C:\Users\me513\Downloads\labels\00290.txt
# Copied 00291.png to C:\Users\me513\Downloads\image\00291.png
# Converted 00291.xml to C:\Users\me513\Downloads\labels\00291.txt
# Copied 00292.png to C:\Users\me513\Downloads\image\00292.png
# Converted 00292.xml to C:\Users\me513\Downloads\labels\00292.txt
# Copied 00293.png to C:\Users\me513\Downloads\image\00293.png
# Converted 00293.xml to C:\Users\me513\Downloads\labels\00293.txt
# Copied 00294.png to C:\Users\me513\Downloads\image\00294.png
# Converted 00294.xml to C:\Users\me513\Downloads\labels\00294.txt
# Copied 00295.png to C:\Users\me513\Downloads\image\00295.png
# Converted 00295.xml to C:\Users\me513\Downloads\labels\00295.txt
# Copied 00296.png to C:\Users\me513\Downloads\image\00296.png
# Converted 00296.xml to C:\Users\me513\Downloads\labels\00296.txt
# Copied 00297.png to C:\Users\me513\Downloads\image\00297.png
# Converted 00297.xml to C:\Users\me513\Downloads\labels\00297.txt
# Copied 00298.png to C:\Users\me513\Downloads\image\00298.png
# Converted 00298.xml to C:\Users\me513\Downloads\labels\00298.txt
# Copied 00299.png to C:\Users\me513\Downloads\image\00299.png
# Converted 00299.xml to C:\Users\me513\Downloads\labels\00299.txt
# Copied 00300.png to C:\Users\me513\Downloads\image\00300.png
# Converted 00300.xml to C:\Users\me513\Downloads\labels\00300.txt
# Copied 00301.png to C:\Users\me513\Downloads\image\00301.png
# Converted 00301.xml to C:\Users\me513\Downloads\labels\00301.txt
# Copied 00302.png to C:\Users\me513\Downloads\image\00302.png
# Converted 00302.xml to C:\Users\me513\Downloads\labels\00302.txt
# Copied 00303.png to C:\Users\me513\Downloads\image\00303.png
# Converted 00303.xml to C:\Users\me513\Downloads\labels\00303.txt
# Copied 00304.png to C:\Users\me513\Downloads\image\00304.png
# Converted 00304.xml to C:\Users\me513\Downloads\labels\00304.txt
# Copied 00305.png to C:\Users\me513\Downloads\image\00305.png
# Converted 00305.xml to C:\Users\me513\Downloads\labels\00305.txt
# Copied 00306.png to C:\Users\me513\Downloads\image\00306.png
# Converted 00306.xml to C:\Users\me513\Downloads\labels\00306.txt
# Copied 00307.png to C:\Users\me513\Downloads\image\00307.png
# Converted 00307.xml to C:\Users\me513\Downloads\labels\00307.txt
# Copied 00308.png to C:\Users\me513\Downloads\image\00308.png
# Converted 00308.xml to C:\Users\me513\Downloads\labels\00308.txt
# Copied 00309.png to C:\Users\me513\Downloads\image\00309.png
# Converted 00309.xml to C:\Users\me513\Downloads\labels\00309.txt
# Copied 00310.png to C:\Users\me513\Downloads\image\00310.png
# Converted 00310.xml to C:\Users\me513\Downloads\labels\00310.txt
# Copied 00311.png to C:\Users\me513\Downloads\image\00311.png
# Converted 00311.xml to C:\Users\me513\Downloads\labels\00311.txt
# Copied 00312.png to C:\Users\me513\Downloads\image\00312.png
# Converted 00312.xml to C:\Users\me513\Downloads\labels\00312.txt
# Copied 00313.png to C:\Users\me513\Downloads\image\00313.png
# Converted 00313.xml to C:\Users\me513\Downloads\labels\00313.txt
# Copied 00314.png to C:\Users\me513\Downloads\image\00314.png
# Converted 00314.xml to C:\Users\me513\Downloads\labels\00314.txt
# Copied 00315.png to C:\Users\me513\Downloads\image\00315.png
# Converted 00315.xml to C:\Users\me513\Downloads\labels\00315.txt
# Copied 00316.png to C:\Users\me513\Downloads\image\00316.png
# Converted 00316.xml to C:\Users\me513\Downloads\labels\00316.txt
# Copied 00317.png to C:\Users\me513\Downloads\image\00317.png
# Converted 00317.xml to C:\Users\me513\Downloads\labels\00317.txt
# Copied 00318.png to C:\Users\me513\Downloads\image\00318.png
# Converted 00318.xml to C:\Users\me513\Downloads\labels\00318.txt
# Copied 00319.png to C:\Users\me513\Downloads\image\00319.png
# Converted 00319.xml to C:\Users\me513\Downloads\labels\00319.txt
# Copied 00320.png to C:\Users\me513\Downloads\image\00320.png
# Converted 00320.xml to C:\Users\me513\Downloads\labels\00320.txt
# Copied 00321.png to C:\Users\me513\Downloads\image\00321.png
# Converted 00321.xml to C:\Users\me513\Downloads\labels\00321.txt
# Copied 00322.png to C:\Users\me513\Downloads\image\00322.png
# Converted 00322.xml to C:\Users\me513\Downloads\labels\00322.txt
# Copied 00323.png to C:\Users\me513\Downloads\image\00323.png
# Converted 00323.xml to C:\Users\me513\Downloads\labels\00323.txt
# Copied 00324.png to C:\Users\me513\Downloads\image\00324.png
# Converted 00324.xml to C:\Users\me513\Downloads\labels\00324.txt
# Copied 00325.png to C:\Users\me513\Downloads\image\00325.png
# Converted 00325.xml to C:\Users\me513\Downloads\labels\00325.txt
# Copied 00326.png to C:\Users\me513\Downloads\image\00326.png
# Converted 00326.xml to C:\Users\me513\Downloads\labels\00326.txt
# Copied 00327.png to C:\Users\me513\Downloads\image\00327.png
# Converted 00327.xml to C:\Users\me513\Downloads\labels\00327.txt
# Copied 00328.png to C:\Users\me513\Downloads\image\00328.png
# Converted 00328.xml to C:\Users\me513\Downloads\labels\00328.txt
# Copied 00329.png to C:\Users\me513\Downloads\image\00329.png
# Converted 00329.xml to C:\Users\me513\Downloads\labels\00329.txt
# Copied 00330.png to C:\Users\me513\Downloads\image\00330.png
# Converted 00330.xml to C:\Users\me513\Downloads\labels\00330.txt
# Copied 00331.png to C:\Users\me513\Downloads\image\00331.png
# Converted 00331.xml to C:\Users\me513\Downloads\labels\00331.txt
# Copied 00332.png to C:\Users\me513\Downloads\image\00332.png
# Converted 00332.xml to C:\Users\me513\Downloads\labels\00332.txt
# Copied 00333.png to C:\Users\me513\Downloads\image\00333.png
# Converted 00333.xml to C:\Users\me513\Downloads\labels\00333.txt
# Copied 00334.png to C:\Users\me513\Downloads\image\00334.png
# Converted 00334.xml to C:\Users\me513\Downloads\labels\00334.txt
# Copied 00335.png to C:\Users\me513\Downloads\image\00335.png
# Converted 00335.xml to C:\Users\me513\Downloads\labels\00335.txt
# Copied 00336.png to C:\Users\me513\Downloads\image\00336.png
# Converted 00336.xml to C:\Users\me513\Downloads\labels\00336.txt
# Copied 00337.png to C:\Users\me513\Downloads\image\00337.png
# Converted 00337.xml to C:\Users\me513\Downloads\labels\00337.txt
# Copied 00338.png to C:\Users\me513\Downloads\image\00338.png
# Converted 00338.xml to C:\Users\me513\Downloads\labels\00338.txt
# Copied 00339.png to C:\Users\me513\Downloads\image\00339.png
# Converted 00339.xml to C:\Users\me513\Downloads\labels\00339.txt
# Copied 00340.png to C:\Users\me513\Downloads\image\00340.png
# Converted 00340.xml to C:\Users\me513\Downloads\labels\00340.txt
# Copied 00341.png to C:\Users\me513\Downloads\image\00341.png
# Converted 00341.xml to C:\Users\me513\Downloads\labels\00341.txt
# Copied 00342.png to C:\Users\me513\Downloads\image\00342.png
# Converted 00342.xml to C:\Users\me513\Downloads\labels\00342.txt
# Copied 00343.png to C:\Users\me513\Downloads\image\00343.png
# Converted 00343.xml to C:\Users\me513\Downloads\labels\00343.txt
# Copied 00344.png to C:\Users\me513\Downloads\image\00344.png
# Converted 00344.xml to C:\Users\me513\Downloads\labels\00344.txt
# Copied 00345.png to C:\Users\me513\Downloads\image\00345.png
# Converted 00345.xml to C:\Users\me513\Downloads\labels\00345.txt
# Copied 00346.png to C:\Users\me513\Downloads\image\00346.png
# Converted 00346.xml to C:\Users\me513\Downloads\labels\00346.txt
# Copied 00347.png to C:\Users\me513\Downloads\image\00347.png
# Converted 00347.xml to C:\Users\me513\Downloads\labels\00347.txt
# Copied 00348.png to C:\Users\me513\Downloads\image\00348.png
# Converted 00348.xml to C:\Users\me513\Downloads\labels\00348.txt
# Copied 00349.png to C:\Users\me513\Downloads\image\00349.png
# Converted 00349.xml to C:\Users\me513\Downloads\labels\00349.txt
# Copied 00350.png to C:\Users\me513\Downloads\image\00350.png
# Converted 00350.xml to C:\Users\me513\Downloads\labels\00350.txt
# Copied 00351.png to C:\Users\me513\Downloads\image\00351.png
# Converted 00351.xml to C:\Users\me513\Downloads\labels\00351.txt
# Copied 00352.png to C:\Users\me513\Downloads\image\00352.png
# Converted 00352.xml to C:\Users\me513\Downloads\labels\00352.txt
# Copied 00353.png to C:\Users\me513\Downloads\image\00353.png
# Converted 00353.xml to C:\Users\me513\Downloads\labels\00353.txt
# Copied 00354.png to C:\Users\me513\Downloads\image\00354.png
# Converted 00354.xml to C:\Users\me513\Downloads\labels\00354.txt
# Copied 00355.png to C:\Users\me513\Downloads\image\00355.png
# Converted 00355.xml to C:\Users\me513\Downloads\labels\00355.txt
# Copied 00356.png to C:\Users\me513\Downloads\image\00356.png
# Converted 00356.xml to C:\Users\me513\Downloads\labels\00356.txt
# Copied 00357.png to C:\Users\me513\Downloads\image\00357.png
# Converted 00357.xml to C:\Users\me513\Downloads\labels\00357.txt
# Copied 00358.png to C:\Users\me513\Downloads\image\00358.png
# Converted 00358.xml to C:\Users\me513\Downloads\labels\00358.txt
# Copied 00359.png to C:\Users\me513\Downloads\image\00359.png
# Converted 00359.xml to C:\Users\me513\Downloads\labels\00359.txt
# Copied 00360.png to C:\Users\me513\Downloads\image\00360.png
# Converted 00360.xml to C:\Users\me513\Downloads\labels\00360.txt
# Copied 00361.png to C:\Users\me513\Downloads\image\00361.png
# Converted 00361.xml to C:\Users\me513\Downloads\labels\00361.txt
# Copied 00362.png to C:\Users\me513\Downloads\image\00362.png
# Converted 00362.xml to C:\Users\me513\Downloads\labels\00362.txt
# Copied 00363.png to C:\Users\me513\Downloads\image\00363.png
# Converted 00363.xml to C:\Users\me513\Downloads\labels\00363.txt
# Copied 00364.png to C:\Users\me513\Downloads\image\00364.png
# Converted 00364.xml to C:\Users\me513\Downloads\labels\00364.txt
# Copied 00365.png to C:\Users\me513\Downloads\image\00365.png
# Converted 00365.xml to C:\Users\me513\Downloads\labels\00365.txt
# Copied 00366.png to C:\Users\me513\Downloads\image\00366.png
# Converted 00366.xml to C:\Users\me513\Downloads\labels\00366.txt
# Copied 00367.png to C:\Users\me513\Downloads\image\00367.png
# Converted 00367.xml to C:\Users\me513\Downloads\labels\00367.txt
# Copied 00368.png to C:\Users\me513\Downloads\image\00368.png
# Converted 00368.xml to C:\Users\me513\Downloads\labels\00368.txt
# Copied 00369.png to C:\Users\me513\Downloads\image\00369.png
# Converted 00369.xml to C:\Users\me513\Downloads\labels\00369.txt
# Copied 00370.png to C:\Users\me513\Downloads\image\00370.png
# Converted 00370.xml to C:\Users\me513\Downloads\labels\00370.txt
# Copied 00371.png to C:\Users\me513\Downloads\image\00371.png
# Converted 00371.xml to C:\Users\me513\Downloads\labels\00371.txt
# Copied 00372.png to C:\Users\me513\Downloads\image\00372.png
# Converted 00372.xml to C:\Users\me513\Downloads\labels\00372.txt
# Copied 00373.png to C:\Users\me513\Downloads\image\00373.png
# Converted 00373.xml to C:\Users\me513\Downloads\labels\00373.txt
# Copied 00374.png to C:\Users\me513\Downloads\image\00374.png
# Converted 00374.xml to C:\Users\me513\Downloads\labels\00374.txt
# Copied 00375.png to C:\Users\me513\Downloads\image\00375.png
# Converted 00375.xml to C:\Users\me513\Downloads\labels\00375.txt
# Copied 00376.png to C:\Users\me513\Downloads\image\00376.png
# Converted 00376.xml to C:\Users\me513\Downloads\labels\00376.txt
# Copied 00377.png to C:\Users\me513\Downloads\image\00377.png
# Converted 00377.xml to C:\Users\me513\Downloads\labels\00377.txt
# Copied 00378.png to C:\Users\me513\Downloads\image\00378.png
# Converted 00378.xml to C:\Users\me513\Downloads\labels\00378.txt
# Copied 00379.png to C:\Users\me513\Downloads\image\00379.png
# Converted 00379.xml to C:\Users\me513\Downloads\labels\00379.txt
# Copied 00380.png to C:\Users\me513\Downloads\image\00380.png
# Converted 00380.xml to C:\Users\me513\Downloads\labels\00380.txt
# Copied 00381.png to C:\Users\me513\Downloads\image\00381.png
# ...
# Converted 00532.xml to C:\Users\me513\Downloads\labels\00532.txt
# Copied 00533.png to C:\Users\me513\Downloads\image\00533.png
# Converted 00533.xml to C:\Users\me513\Downloads\labels\00533.txt
# Copied 00534.png to C:\Users\me513\Downloads\image\00534.png
# Converted 00534.xml to C:\Users\me513\Downloads\labels\00534.txt
# Copied 00535.png to C:\Users\me513\Downloads\image\00535.png
# Converted 00535.xml to C:\Users\me513\Downloads\labels\00535.txt
# Copied 00536.png to C:\Users\me513\Downloads\image\00536.png
# Converted 00536.xml to C:\Users\me513\Downloads\labels\00536.txt
# Copied 00537.png to C:\Users\me513\Downloads\image\00537.png
# Converted 00537.xml to C:\Users\me513\Downloads\labels\00537.txt
# Copied 00538.png to C:\Users\me513\Downloads\image\00538.png
# Converted 00538.xml to C:\Users\me513\Downloads\labels\00538.txt
# Copied 00539.png to C:\Users\me513\Downloads\image\00539.png
# Converted 00539.xml to C:\Users\me513\Downloads\labels\00539.txt
# Copied 00540.png to C:\Users\me513\Downloads\image\00540.png
# Converted 00540.xml to C:\Users\me513\Downloads\labels\00540.txt
# Copied 00541.png to C:\Users\me513\Downloads\image\00541.png
# Converted 00541.xml to C:\Users\me513\Downloads\labels\00541.txt
# Copied 00542.png to C:\Users\me513\Downloads\image\00542.png
# Converted 00542.xml to C:\Users\me513\Downloads\labels\00542.txt
# Copied 00543.png to C:\Users\me513\Downloads\image\00543.png
# Converted 00543.xml to C:\Users\me513\Downloads\labels\00543.txt
# Copied 00544.png to C:\Users\me513\Downloads\image\00544.png
# Converted 00544.xml to C:\Users\me513\Downloads\labels\00544.txt
# Copied 00545.png to C:\Users\me513\Downloads\image\00545.png
# Converted 00545.xml to C:\Users\me513\Downloads\labels\00545.txt
# Copied 00546.png to C:\Users\me513\Downloads\image\00546.png
# Converted 00546.xml to C:\Users\me513\Downloads\labels\00546.txt
# Copied 00547.png to C:\Users\me513\Downloads\image\00547.png
# Converted 00547.xml to C:\Users\me513\Downloads\labels\00547.txt
# Copied 00548.png to C:\Users\me513\Downloads\image\00548.png
# Converted 00548.xml to C:\Users\me513\Downloads\labels\00548.txt
# Copied 00549.png to C:\Users\me513\Downloads\image\00549.png
# Converted 00549.xml to C:\Users\me513\Downloads\labels\00549.txt
# Copied 00550.png to C:\Users\me513\Downloads\image\00550.png
# Converted 00550.xml to C:\Users\me513\Downloads\labels\00550.txt
# Copied 00551.png to C:\Users\me513\Downloads\image\00551.png
# Converted 00551.xml to C:\Users\me513\Downloads\labels\00551.txt
# Copied 00552.png to C:\Users\me513\Downloads\image\00552.png
# Converted 00552.xml to C:\Users\me513\Downloads\labels\00552.txt
# Copied 00553.png to C:\Users\me513\Downloads\image\00553.png
# Converted 00553.xml to C:\Users\me513\Downloads\labels\00553.txt
# Copied 00554.png to C:\Users\me513\Downloads\image\00554.png
# Converted 00554.xml to C:\Users\me513\Downloads\labels\00554.txt
# Copied 00555.png to C:\Users\me513\Downloads\image\00555.png
# Converted 00555.xml to C:\Users\me513\Downloads\labels\00555.txt
# Copied 00556.png to C:\Users\me513\Downloads\image\00556.png
# Converted 00556.xml to C:\Users\me513\Downloads\labels\00556.txt
# Copied 00557.png to C:\Users\me513\Downloads\image\00557.png
# Converted 00557.xml to C:\Users\me513\Downloads\labels\00557.txt
# Copied 00558.png to C:\Users\me513\Downloads\image\00558.png
# Converted 00558.xml to C:\Users\me513\Downloads\labels\00558.txt
# Copied 00559.png to C:\Users\me513\Downloads\image\00559.png
# Converted 00559.xml to C:\Users\me513\Downloads\labels\00559.txt
# Copied 00560.png to C:\Users\me513\Downloads\image\00560.png
# Converted 00560.xml to C:\Users\me513\Downloads\labels\00560.txt
# Copied 00561.png to C:\Users\me513\Downloads\image\00561.png
# Converted 00561.xml to C:\Users\me513\Downloads\labels\00561.txt
# Copied 00562.png to C:\Users\me513\Downloads\image\00562.png
# Converted 00562.xml to C:\Users\me513\Downloads\labels\00562.txt
# Copied 00563.png to C:\Users\me513\Downloads\image\00563.png
# Converted 00563.xml to C:\Users\me513\Downloads\labels\00563.txt
# Copied 00564.png to C:\Users\me513\Downloads\image\00564.png
# Converted 00564.xml to C:\Users\me513\Downloads\labels\00564.txt
# Copied 00565.png to C:\Users\me513\Downloads\image\00565.png
# Converted 00565.xml to C:\Users\me513\Downloads\labels\00565.txt
# Copied 00566.png to C:\Users\me513\Downloads\image\00566.png
# Converted 00566.xml to C:\Users\me513\Downloads\labels\00566.txt
# Copied 00567.png to C:\Users\me513\Downloads\image\00567.png
# Converted 00567.xml to C:\Users\me513\Downloads\labels\00567.txt
# Copied 00568.png to C:\Users\me513\Downloads\image\00568.png
# Converted 00568.xml to C:\Users\me513\Downloads\labels\00568.txt
# Copied 00569.png to C:\Users\me513\Downloads\image\00569.png
# Converted 00569.xml to C:\Users\me513\Downloads\labels\00569.txt
# Copied 00570.png to C:\Users\me513\Downloads\image\00570.png
# Converted 00570.xml to C:\Users\me513\Downloads\labels\00570.txt
# Copied 00571.png to C:\Users\me513\Downloads\image\00571.png
# Converted 00571.xml to C:\Users\me513\Downloads\labels\00571.txt
# Copied 00572.png to C:\Users\me513\Downloads\image\00572.png
# Converted 00572.xml to C:\Users\me513\Downloads\labels\00572.txt
# Copied 00573.png to C:\Users\me513\Downloads\image\00573.png
# Converted 00573.xml to C:\Users\me513\Downloads\labels\00573.txt
# Copied 00574.png to C:\Users\me513\Downloads\image\00574.png
# Converted 00574.xml to C:\Users\me513\Downloads\labels\00574.txt
# Copied 00575.png to C:\Users\me513\Downloads\image\00575.png
# Converted 00575.xml to C:\Users\me513\Downloads\labels\00575.txt
# Copied 00576.png to C:\Users\me513\Downloads\image\00576.png
# Converted 00576.xml to C:\Users\me513\Downloads\labels\00576.txt
# Copied 00577.png to C:\Users\me513\Downloads\image\00577.png
# Converted 00577.xml to C:\Users\me513\Downloads\labels\00577.txt
# Copied 00578.png to C:\Users\me513\Downloads\image\00578.png
# Converted 00578.xml to C:\Users\me513\Downloads\labels\00578.txt
# Copied 00579.png to C:\Users\me513\Downloads\image\00579.png
# Converted 00579.xml to C:\Users\me513\Downloads\labels\00579.txt
# Copied 00580.png to C:\Users\me513\Downloads\image\00580.png
# Converted 00580.xml to C:\Users\me513\Downloads\labels\00580.txt
# Copied 00581.png to C:\Users\me513\Downloads\image\00581.png
# Converted 00581.xml to C:\Users\me513\Downloads\labels\00581.txt
# Copied 00582.png to C:\Users\me513\Downloads\image\00582.png
# Converted 00582.xml to C:\Users\me513\Downloads\labels\00582.txt
# Copied 00583.png to C:\Users\me513\Downloads\image\00583.png
# Converted 00583.xml to C:\Users\me513\Downloads\labels\00583.txt
# Copied 00584.png to C:\Users\me513\Downloads\image\00584.png
# Converted 00584.xml to C:\Users\me513\Downloads\labels\00584.txt
# Copied 00585.png to C:\Users\me513\Downloads\image\00585.png
# Converted 00585.xml to C:\Users\me513\Downloads\labels\00585.txt
# Copied 00586.png to C:\Users\me513\Downloads\image\00586.png
# Converted 00586.xml to C:\Users\me513\Downloads\labels\00586.txt
# Copied 00587.png to C:\Users\me513\Downloads\image\00587.png
# Converted 00587.xml to C:\Users\me513\Downloads\labels\00587.txt
# Copied 00588.png to C:\Users\me513\Downloads\image\00588.png
# Converted 00588.xml to C:\Users\me513\Downloads\labels\00588.txt
# Copied 00589.png to C:\Users\me513\Downloads\image\00589.png
# Converted 00589.xml to C:\Users\me513\Downloads\labels\00589.txt
# Copied 00590.png to C:\Users\me513\Downloads\image\00590.png
# Converted 00590.xml to C:\Users\me513\Downloads\labels\00590.txt
# Copied 00591.png to C:\Users\me513\Downloads\image\00591.png
# Converted 00591.xml to C:\Users\me513\Downloads\labels\00591.txt
# Copied 00592.png to C:\Users\me513\Downloads\image\00592.png
# Converted 00592.xml to C:\Users\me513\Downloads\labels\00592.txt
# Copied 00593.png to C:\Users\me513\Downloads\image\00593.png
# Converted 00593.xml to C:\Users\me513\Downloads\labels\00593.txt
# Copied 00594.png to C:\Users\me513\Downloads\image\00594.png
# Converted 00594.xml to C:\Users\me513\Downloads\labels\00594.txt
# Copied 00595.png to C:\Users\me513\Downloads\image\00595.png
# Converted 00595.xml to C:\Users\me513\Downloads\labels\00595.txt
# Copied 00596.png to C:\Users\me513\Downloads\image\00596.png
# Converted 00596.xml to C:\Users\me513\Downloads\labels\00596.txt
# Copied 00597.png to C:\Users\me513\Downloads\image\00597.png
# Converted 00597.xml to C:\Users\me513\Downloads\labels\00597.txt
# Copied 00598.png to C:\Users\me513\Downloads\image\00598.png
# Converted 00598.xml to C:\Users\me513\Downloads\labels\00598.txt
# Copied 00599.png to C:\Users\me513\Downloads\image\00599.png
# Converted 00599.xml to C:\Users\me513\Downloads\labels\00599.txt
# Copied 00600.png to C:\Users\me513\Downloads\image\00600.png
# Converted 00600.xml to C:\Users\me513\Downloads\labels\00600.txt
# Copied 00601.png to C:\Users\me513\Downloads\image\00601.png
# Converted 00601.xml to C:\Users\me513\Downloads\labels\00601.txt
# Copied 00602.png to C:\Users\me513\Downloads\image\00602.png
# Converted 00602.xml to C:\Users\me513\Downloads\labels\00602.txt
# Copied 00603.png to C:\Users\me513\Downloads\image\00603.png
# Converted 00603.xml to C:\Users\me513\Downloads\labels\00603.txt
# Copied 00604.png to C:\Users\me513\Downloads\image\00604.png
# Converted 00604.xml to C:\Users\me513\Downloads\labels\00604.txt
# Copied 00605.png to C:\Users\me513\Downloads\image\00605.png
# Converted 00605.xml to C:\Users\me513\Downloads\labels\00605.txt
# Copied 00606.png to C:\Users\me513\Downloads\image\00606.png
# Converted 00606.xml to C:\Users\me513\Downloads\labels\00606.txt
# Copied 00607.png to C:\Users\me513\Downloads\image\00607.png
# Converted 00607.xml to C:\Users\me513\Downloads\labels\00607.txt
# Copied 00608.png to C:\Users\me513\Downloads\image\00608.png
# Converted 00608.xml to C:\Users\me513\Downloads\labels\00608.txt
# Copied 00609.png to C:\Users\me513\Downloads\image\00609.png
# Converted 00609.xml to C:\Users\me513\Downloads\labels\00609.txt
# Copied 00610.png to C:\Users\me513\Downloads\image\00610.png
# Converted 00610.xml to C:\Users\me513\Downloads\labels\00610.txt
# Copied 00611.png to C:\Users\me513\Downloads\image\00611.png
# Converted 00611.xml to C:\Users\me513\Downloads\labels\00611.txt
# Copied 00612.png to C:\Users\me513\Downloads\image\00612.png
# Converted 00612.xml to C:\Users\me513\Downloads\labels\00612.txt
# Copied 00613.png to C:\Users\me513\Downloads\image\00613.png
# Converted 00613.xml to C:\Users\me513\Downloads\labels\00613.txt
# Copied 00614.png to C:\Users\me513\Downloads\image\00614.png
# Converted 00614.xml to C:\Users\me513\Downloads\labels\00614.txt
# Copied 00615.png to C:\Users\me513\Downloads\image\00615.png
# Converted 00615.xml to C:\Users\me513\Downloads\labels\00615.txt
# Copied 00616.png to C:\Users\me513\Downloads\image\00616.png
# Converted 00616.xml to C:\Users\me513\Downloads\labels\00616.txt
# Copied 00617.png to C:\Users\me513\Downloads\image\00617.png
# Converted 00617.xml to C:\Users\me513\Downloads\labels\00617.txt
# Copied 00618.png to C:\Users\me513\Downloads\image\00618.png
# Converted 00618.xml to C:\Users\me513\Downloads\labels\00618.txt
# Copied 00619.png to C:\Users\me513\Downloads\image\00619.png
# Converted 00619.xml to C:\Users\me513\Downloads\labels\00619.txt
# Copied 00620.png to C:\Users\me513\Downloads\image\00620.png
# Converted 00620.xml to C:\Users\me513\Downloads\labels\00620.txt
# Copied 00621.png to C:\Users\me513\Downloads\image\00621.png
# Converted 00621.xml to C:\Users\me513\Downloads\labels\00621.txt
# Copied 00622.png to C:\Users\me513\Downloads\image\00622.png
# Converted 00622.xml to C:\Users\me513\Downloads\labels\00622.txt
# Copied 00623.png to C:\Users\me513\Downloads\image\00623.png
# Converted 00623.xml to C:\Users\me513\Downloads\labels\00623.txt
# Copied 00624.png to C:\Users\me513\Downloads\image\00624.png
# Converted 00624.xml to C:\Users\me513\Downloads\labels\00624.txt
# Copied 00625.png to C:\Users\me513\Downloads\image\00625.png
# Converted 00625.xml to C:\Users\me513\Downloads\labels\00625.txt
# Copied 00626.png to C:\Users\me513\Downloads\image\00626.png
# Converted 00626.xml to C:\Users\me513\Downloads\labels\00626.txt
# Copied 00627.png to C:\Users\me513\Downloads\image\00627.png
# Converted 00627.xml to C:\Users\me513\Downloads\labels\00627.txt
# Copied 00628.png to C:\Users\me513\Downloads\image\00628.png
# Converted 00628.xml to C:\Users\me513\Downloads\labels\00628.txt
# Copied 00629.png to C:\Users\me513\Downloads\image\00629.png
# Converted 00629.xml to C:\Users\me513\Downloads\labels\00629.txt
# Copied 00630.png to C:\Users\me513\Downloads\image\00630.png
# Converted 00630.xml to C:\Users\me513\Downloads\labels\00630.txt
# Copied 00631.png to C:\Users\me513\Downloads\image\00631.png
# Converted 00631.xml to C:\Users\me513\Downloads\labels\00631.txt
# Copied 00632.png to C:\Users\me513\Downloads\image\00632.png
# Converted 00632.xml to C:\Users\me513\Downloads\labels\00632.txt
# Copied 00633.png to C:\Users\me513\Downloads\image\00633.png
# Converted 00633.xml to C:\Users\me513\Downloads\labels\00633.txt
# Copied 00634.png to C:\Users\me513\Downloads\image\00634.png
# Converted 00634.xml to C:\Users\me513\Downloads\labels\00634.txt
# Copied 00635.png to C:\Users\me513\Downloads\image\00635.png
# Converted 00635.xml to C:\Users\me513\Downloads\labels\00635.txt
# Copied 00636.png to C:\Users\me513\Downloads\image\00636.png
# Converted 00636.xml to C:\Users\me513\Downloads\labels\00636.txt
# Copied 00637.png to C:\Users\me513\Downloads\image\00637.png
# Converted 00637.xml to C:\Users\me513\Downloads\labels\00637.txt
# Copied 00638.png to C:\Users\me513\Downloads\image\00638.png
# Converted 00638.xml to C:\Users\me513\Downloads\labels\00638.txt
# Copied 00639.png to C:\Users\me513\Downloads\image\00639.png
# Converted 00639.xml to C:\Users\me513\Downloads\labels\00639.txt
# Copied 00640.png to C:\Users\me513\Downloads\image\00640.png
# Converted 00640.xml to C:\Users\me513\Downloads\labels\00640.txt
# Copied 00641.png to C:\Users\me513\Downloads\image\00641.png
# Converted 00641.xml to C:\Users\me513\Downloads\labels\00641.txt
# Copied 00642.png to C:\Users\me513\Downloads\image\00642.png
# Converted 00642.xml to C:\Users\me513\Downloads\labels\00642.txt
# Copied 00643.png to C:\Users\me513\Downloads\image\00643.png
# Converted 00643.xml to C:\Users\me513\Downloads\labels\00643.txt
# Copied 00644.png to C:\Users\me513\Downloads\image\00644.png
# Converted 00644.xml to C:\Users\me513\Downloads\labels\00644.txt
# Copied 00645.png to C:\Users\me513\Downloads\image\00645.png
# Converted 00645.xml to C:\Users\me513\Downloads\labels\00645.txt
# Copied 00646.png to C:\Users\me513\Downloads\image\00646.png
# Converted 00646.xml to C:\Users\me513\Downloads\labels\00646.txt
# Copied 00647.png to C:\Users\me513\Downloads\image\00647.png
# Converted 00647.xml to C:\Users\me513\Downloads\labels\00647.txt
# Copied 00648.png to C:\Users\me513\Downloads\image\00648.png
# Converted 00648.xml to C:\Users\me513\Downloads\labels\00648.txt
# Copied 00649.png to C:\Users\me513\Downloads\image\00649.png
# Converted 00649.xml to C:\Users\me513\Downloads\labels\00649.txt
# Copied 00650.png to C:\Users\me513\Downloads\image\00650.png
# Converted 00650.xml to C:\Users\me513\Downloads\labels\00650.txt
# Copied 00651.png to C:\Users\me513\Downloads\image\00651.png
# Converted 00651.xml to C:\Users\me513\Downloads\labels\00651.txt
# Copied 00652.png to C:\Users\me513\Downloads\image\00652.png
# Converted 00652.xml to C:\Users\me513\Downloads\labels\00652.txt
# Copied 00653.png to C:\Users\me513\Downloads\image\00653.png
# Converted 00653.xml to C:\Users\me513\Downloads\labels\00653.txt
# Copied 00654.png to C:\Users\me513\Downloads\image\00654.png
# Converted 00654.xml to C:\Users\me513\Downloads\labels\00654.txt
# Copied 00655.png to C:\Users\me513\Downloads\image\00655.png
# Converted 00655.xml to C:\Users\me513\Downloads\labels\00655.txt
# Copied 00656.png to C:\Users\me513\Downloads\image\00656.png
# Converted 00656.xml to C:\Users\me513\Downloads\labels\00656.txt
# Copied 00657.png to C:\Users\me513\Downloads\image\00657.png
# Converted 00657.xml to C:\Users\me513\Downloads\labels\00657.txt
# Copied 00658.png to C:\Users\me513\Downloads\image\00658.png
# Converted 00658.xml to C:\Users\me513\Downloads\labels\00658.txt
# All files processed successfully.

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import xml.etree.ElementTree as ET

# Function to parse XML annotations
def parse_xml(xml_path):
    """
    Parse an XML file to extract bounding box coordinates.
    
    Parameters:
    - xml_path: Path to the XML file.
    
    Returns:
    - List of bounding boxes, each in the format [xmin, ymin, xmax, ymax].
    """
    tree = ET.parse(xml_path)
    root = tree.getroot()
    boxes = []
    
    for obj in root.findall('object'):
        bbox = obj.find('bndbox')
        xmin = int(bbox.find('xmin').text)
        ymin = int(bbox.find('ymin').text)
        xmax = int(bbox.find('xmax').text)
        ymax = int(bbox.find('ymax').text)
        boxes.append([xmin, ymin, xmax, ymax])
    
    return boxes

# Function to display an image with annotation boxes
# Function to display an image with annotation boxes
def show_image_with_boxes(image_path, boxes):
    """
    Display an image with annotation boxes.
    
    Parameters:
    - image_path: Path to the image file.
    - boxes: List of bounding boxes, each in the format [xmin, ymin, xmax, ymax].
    """
    image = Image.open(image_path)
    fig, ax = plt.subplots(1)
    ax.imshow(image)
    
    for box in boxes:
        xmin, ymin, xmax, ymax = box
        rect = patches.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, linewidth=2, edgecolor='red', facecolor='none')
        ax.add_patch(rect)
    
    plt.show()
    plt.close(fig)  # Close the figure after displaying


# Main function to loop over a directory
def process_all_images_with_annotations(folder_path, image_extension='.png', annotation_extension='.xml'):
    """
    Loop through all images and annotations in a folder and display each image with its boxes.
    
    Parameters:
    - folder_path: Path to the folder containing images and XML annotations.
    - image_extension: Extension for image files (e.g., '.jpg').
    - annotation_extension: Extension for annotation files (e.g., '.xml').
    """
    for filename in os.listdir(folder_path):
        if filename.endswith(image_extension):
            # Image and annotation filenames
            image_path = os.path.join(folder_path, filename)
            xml_path = os.path.join(folder_path, filename.replace(image_extension, annotation_extension))
            
            if os.path.exists(xml_path):  # Check if annotation file exists
                boxes = parse_xml(xml_path)
                show_image_with_boxes(image_path, boxes)
                print(xml_path)
            else:
                print(f"No annotation file found for {filename}")

# Example usage
folder_path = r"C:\Users\me513\Downloads\images"
process_all_images_with_annotations(folder_path)

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
from ultralytics import YOLO
import torchvision.ops as ops
# Load a pretrained YOLO model
model = YOLO("yolo11n.pt")

boxes = ops.nms(boxes, scores, iou_thres)

results = model.train(
    data=r"C:\Users\me513\Downloads\yolo\data.yaml",  # path to your YAML file
    batch=1,  # You can try increasing this depending on your GPU
    epochs=100,
    imgsz=640,  # Try a smaller image size like 640 for faster training
    device=0  # Specify GPU if you have one (use -1 for CPU)
)

# %%
import os
from collections import defaultdict

# Path to the directory with YOLO label files
labels_dir = r"C:\Users\me513\Downloads\yolo\train\labels"
class_counts = defaultdict(int)

# Loop through all .txt files in the labels directory
for label_file in os.listdir(labels_dir):
    if label_file.endswith('.txt'):
        # Read each line in the file and count class instances
        with open(os.path.join(labels_dir, label_file), 'r') as file:
            for line in file:
                class_id = int(line.split()[0])  # Extract the class ID (first element)
                class_counts[class_id] += 1      # Increment count for the class ID

# Print the number of instances for each class
for class_id, count in class_counts.items():
    print(f"Class {class_id}: {count} instances")
# Out:
# Class 1: 702 instances
# Class 0: 1541 instances

# %%
# Evaluate the model on the test dataset
results = model.val(data=r"C:\Users\me513\Downloads\projects\data.yaml")

# Print evaluation results
print(results)
